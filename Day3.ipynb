# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshikutty0528-cmyk/Data-Analytics-using-PythonProject/blob/main/Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
try:
 num=int(input("enter the number:"))
 print(num)
except:
 print("invalid input")
# Out:
# enter the number:123
# 123

# %%
def attendance_percentage(attended, total):
    percentage = (attended / total) * 100
    return round(percentage, 2)


def check_eligibility(percent):
    if percent >= 75:
        return "ELIGIBLE ✓"
    else:
        return "NOT ELIGIBLE ✗"


try:
    total = int(input("Total Classes: "))
    attended = int(input("Classes Attended: "))

    pct = attendance_percentage(attended, total)
    status = check_eligibility(pct)

    print(f"Attendance: {pct}%")
    print(f"Status: {status}")

except ValueError:
    print("Enter valid numbers")
# Out:
# Total Classes: 80
# Classes Attended: 70
# Attendance: 87.5%
# Status: ELIGIBLE ✓

# %%
import numpy as np
marks = np.array([60, 90, 78, 95])
print(marks)
# Out:
# [60 90 78 95]

# %%
import numpy as np
students = np.array([
    [60, 90],
    [78, 87],
    [67, 60]
])
print(students)
# Out:
# [[60 90]
#  [78 87]
#  [67 60]]
