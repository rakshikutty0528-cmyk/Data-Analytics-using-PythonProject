# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshikutty0528-cmyk/Data-Analytics-using-PythonProject/blob/main/day7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {
    'Name': ['John', 'Mary', 'John'],
    'Sales': [1000, 1500, 1000]
}

df = pd.DataFrame(data)

print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
import pandas as pd

data = {
    'Name': ['John', 'Mary', 'John'],
    'Sales': [1000, 1500, 1000]
}

df = pd.DataFrame(data)

print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
import pandas as pd

data = {
    'emp_nm': ['John', 'Mary'],
    'emp_sal': [25000, 30000]
}

df = pd.DataFrame(data)

df.rename(columns={
    'emp_nm': 'Employee Name',
    'emp_sal': 'Employee Salary'
}, inplace=True)

print(df)
# Out:
#   Employee Name  Employee Salary
# 0          John            25000
# 1          Mary            30000

# %%
import pandas as pd

data = {
    "Region": ["South", "North", "East", "West", "South", "North"],
    "Product": ["Laptop", "Mobile", "Laptop", "Tablet", "Mobile", "Tablet"],
    "Sales": [50000, 30000, 45000, 25000, 20000, 35000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Region Product  Sales
# 0  South  Laptop  50000
# 1  North  Mobile  30000
# 2   East  Laptop  45000
# 3   West  Tablet  25000
# 4  South  Mobile  20000
# 5  North  Tablet  35000

# %%
high_sales = df[df["Sales"] > 30000]

print(high_sales)
# Out:
#   Region Product  Sales
# 0  South  Laptop  50000
# 2   East  Laptop  45000
# 5  North  Tablet  35000

# %%
south_sales = df[df["Region"] == "South"]

print(south_sales)
# Out:
#   Region Product  Sales
# 0  South  Laptop  50000
# 4  South  Mobile  20000

# %% [markdown]
# Practice : Employee dataset exploration

# %%
import pandas as pd

# Create product sales dataset
data = {
    "Product": ["Pen", "Pencil", "Book", "Eraser"],
    "Sales": [200, 150, 500, 100]
}

df = pd.DataFrame(data)

# Display dataset
print("Product Sales Dataset")
print(df)

# Total sales
print("\nTotal Sales:", df["Sales"].sum())

# Average sales
print("Average Sales:", df["Sales"].mean())

# Highest sales
print("Highest Sales:", df["Sales"].max())
# Out:
# Product Sales Dataset
#   Product  Sales
# 0     Pen    200
# 1  Pencil    150
# 2    Book    500
# 3  Eraser    100
#
# Total Sales: 950
# Average Sales: 237.5
# Highest Sales: 500
